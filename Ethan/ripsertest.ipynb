# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.spatial.distance as d
import ripser
import tadasets
from persim import plot_diagrams

from persim.visuals import plot_a_bar

import gudhi

# %%
data = pd.read_csv("../datasets/CCMathTopologyScavengerHunt/points11.csv")
data = np.array(data)
print(data)

ripsOut = ripser.ripser(data, maxdim = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("../datasets/CCMathTopologyScavengerHunt/points11.csv")
#       2 data = np.array(data)
#       3 print(data)
#
# NameError: name 'pd' is not defined

# %%
print(ripsOut.keys())
ripsDGMS = ripsOut["dgms"]
plot_diagrams(ripsDGMS)
# Out:
# dict_keys(['dgms', 'cocycles', 'num_edges', 'dperm2all', 'idx_perm', 'r_cover'])
